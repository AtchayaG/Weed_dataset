# %%
import pandas as pd
import numpy as np
df=pd.read_csv("E:\StudyContent\PythonCOntent\week5\data\Weed_Price.csv")
df.shape
#to know the number of rows and columns
# Out:
# (22899, 8)

# %%
df.head(5)
#to print the first 5 rows
# Out:
#         State   HighQ  HighQN    MedQ  MedQN    LowQ  LowQN        date
# 0     Alabama  339.06    1042  198.64    933  149.49    123  2014-01-01
# 1      Alaska  288.75     252  260.60    297  388.58     26  2014-01-01
# 2     Arizona  303.31    1941  209.35   1625  189.45    222  2014-01-01
# 3    Arkansas  361.85     576  185.62    544  125.87    112  2014-01-01
# 4  California  248.78   12096  193.56  12812  192.92    778  2014-01-01

# %%
df.iloc[6]
#to print the 6th row
# Out:
# State     Connecticut
# HighQ           347.9
# HighQN           1294
# MedQ           273.97
# MedQN            1316
# LowQ           257.36
# LowQN              91
# date       2014-01-01
# Name: 6, dtype: object

# %%
df.iloc[:,:2]
#to print all rows for first 2 columns
# Out:
#                       State   HighQ
# 0                   Alabama  339.06
# 1                    Alaska  288.75
# 2                   Arizona  303.31
# 3                  Arkansas  361.85
# 4                California  248.78
# 5                  Colorado  236.31
# 6               Connecticut  347.90
# 7                  Delaware  373.18
# 8      District of Columbia  352.26
# 9                   Florida  306.43
# 10                  Georgia  332.21
# 11                   Hawaii  310.96
# 12                    Idaho  276.05
# 13                 Illinois  359.74
# 14                  Indiana  336.80
# 15                     Iowa  371.70
# 16                   Kansas  353.51
# 17                 Kentucky  337.33
# 18                Louisiana  377.71
# 19                    Maine  321.10
# 20                  Montana  279.73
# 21                 Nebraska  352.64
# 22                   Nevada  269.61
# 23            New Hampshire  366.47
# 24               New Jersey  354.91
# ...

# %%
df[df['HiqhQ'.notnull()]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e1966c35ac45> in <module>()
# ----> 1 df[df['HiqhQ'.notnull()]]
#
# AttributeError: 'str' object has no attribute 'notnull'
